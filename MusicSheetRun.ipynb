# %%
# %run AudioFileInput.py
# Out:
# int16 44100 2.2675736961451248e-05
# (333507, 2)
# 7.56
# 2
# left_channel shape:  (333507,)
# Count of values over threshold:  1
# Frequencies over threshold:  [1050.0]
# Pitches in this timestep:  {'C6'}
# sample interval:  0 4410 {'C6'}
# Count of values over threshold:  1
# Frequencies over threshold:  [520.0]
# Pitches in this timestep:  {'C5'}
# sample interval:  4410 8820 {'C5'}
# Count of values over threshold:  1
# Frequencies over threshold:  [520.0]
# Pitches in this timestep:  {'C5'}
# sample interval:  8820 13230 {'C5'}
# Count of values over threshold:  3
# Frequencies over threshold:  [520.0, 530.0, 1050.0]
# Pitches in this timestep:  {'C6', 'C5'}
# sample interval:  13230 17640 {'C6', 'C5'}
# Count of values over threshold:  2
# Frequencies over threshold:  [520.0, 1050.0]
# Pitches in this timestep:  {'C6', 'C5'}
# sample interval:  17640 22050 {'C6', 'C5'}
# Count of values over threshold:  2
# Frequencies over threshold:  [530.0, 1050.0]
# ...
